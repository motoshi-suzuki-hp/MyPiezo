# %%
# ライブラリのインポート
import pymatgen
from pymatgen.ext.matproj import MPRester
import itertools
import pandas as pd



# Materials Projectに登録して取得したAPIキーを入力
API_KEY = 'ZwAKxVzXCtOfU6BZZzt3xGRkHcCSIxOn'

# %%
with MPRester(API_KEY) as m:
    df_MP = pd.DataFrame()
    #compoundはlist型
    for elements in ['mp-1229280','mp-661']:
        compound = m.get_data(elements, data_type='vasp')
        df_mp = pd.DataFrame(compound)           
        df_MP = pd.concat([df_MP,df_mp])

# %%
pd.set_option('display.max_columns', 140)

# %%
df_MP
# Out:
#       energy  energy_per_atom      volume  formation_energy_per_atom  nsites  \
# 0 -80.931503        -1.686073  999.608581                   0.032400      48
# 0 -29.779700        -7.444925   42.527283                  -1.595901       4
#
#          unit_cell_formula pretty_formula  is_hubbard  elements  nelements  \
# 0  {'Cd': 40.0, 'Ni': 8.0}          Cd5Ni       False  [Cd, Ni]          2
# 0    {'Al': 2.0, 'N': 2.0}            AlN       False   [Al, N]          2
#
#    e_above_hull hubbards  is_compatible  \
# 0      0.039197       {}           True
# 0      0.000000       {}           True
#
#                                           spacegroup  \
# 0  {'symprec': 0.1, 'source': 'spglib', 'symbol':...
# 0  {'symprec': 0.1, 'source': 'spglib', 'symbol':...
#
#                                             task_ids  band_gap   density  \
# 0                           [mp-1229280, mp-1328167]    0.0000  8.249445
# ...

# %%
# !pip install mp_api

# %%
# !pip install emmet_api

# %%
conda list
# Out:
# # packages in environment at C:\Users\white\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py39haa95532_0
# aiohttp                   3.8.1            py39h2bbff1b_1
# aiosignal                 1.2.0              pyhd3eb1b0_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  2022.05                  py39_0
# anaconda-client           1.9.0            py39haa95532_0
# anaconda-navigator        2.2.0            py39haa95532_0
# anaconda-project          0.10.2             pyhd3eb1b0_0
# anyio                     3.5.0            py39haa95532_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39h2bbff1b_0
# arrow                     1.2.2              pyhd3eb1b0_0
# ase                       3.22.1             pyhd8ed1ab_1    conda-forge
# ...

# %%
from mp_api.client import MPRester
# from emmet import HasProps

with MPRester(API_KEY) as mpr: 

    docs = mpr.summary.search(has_props = [HasProps.piezoelectric], fields=["material_id"])
    mpids = [doc.material_id for doc in docs]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 from mp_api.client import MPRester
#       2 # from emmet import HasProps
#       4 with MPRester(API_KEY) as mpr:
#
# ModuleNotFoundError: No module named 'mp_api'
